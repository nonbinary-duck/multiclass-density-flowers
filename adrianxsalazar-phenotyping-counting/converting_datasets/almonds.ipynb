# %%
from dataclasses import dataclass
import pandas as pd
import typing as T
import numpy as np
import shutil
import json
import math
import cv2
import os

df = pd.read_csv("acfr-fruit-dataset/almonds/annotations/fromEast_56_04_IMG_4328_i900j2700.csv")

# %%
df
# Out:
#     #item           x             y    dx    dy  label
# 0       0  107.142857  2.585714e+02  16.0  14.0      1
# 1       1  133.333333  2.123810e+02  16.0  14.0      1
# 2       2   98.571429  2.114286e+02  14.0  18.0      1
# 3       3   89.047619  2.109524e+02  14.0  12.0      1
# 4       4   75.714286  2.195238e+02  18.0  14.0      1
# 5       5   40.952381  2.157143e+02  12.0  14.0      1
# 6       6   42.857143  2.271429e+02  14.0  16.0      1
# 7       7   31.428571  1.714286e+02  14.0  14.0      1
# 8       8   36.190476  1.666667e+02  12.0  14.0      1
# 9       9   38.095238  9.000000e+01  14.0  18.0      1
# 10     10    7.619048  9.571429e+01  14.0  16.0      1
# 11     11   43.809524  2.664535e-14  14.0  10.0      1
# 12     12   40.952381  3.333333e+00  14.0  16.0      1
# 13     13   10.476190  4.333333e+01  14.0  14.0      1
# 14     14    0.476190  4.333333e+01  10.0  14.0      1
# 15     15    1.428571  2.595238e+02  12.0  14.0      1
# 16     16   69.047619  8.714286e+01  16.0  12.0      1
# 17     17  282.380952  1.533333e+02  14.0  16.0      1
# 18     18  275.714286  1.400000e+02  18.0  14.0      1
# 19     19  277.619048  1.233333e+02  16.0  16.0      1
# 20     20  285.238095  1.290476e+02  16.0  14.0      1
# 21     21  288.095238  1.423810e+02  16.0  18.0      1

# %%
@dataclass
class Segment:
    xmin: int;
    ymin: int;
    xmax: int;
    ymax: int;
    name: str;
    pose: str;
    # Not always present in dataset, so I just set to "None"
    segmented: int;
    truncated: int;
    difficult: int;

@dataclass
class Image:
    img_path: str;
    # xml_path: str;
    # xml_data: any;
    b_boxes:  T.List[Segment];

def get_images(i_dir: str, annotation, img_ext = ".png", radius = False) -> T.List[Image]:
    """
    Returns all images within a directory (not recursive?)
    """
    images: T.List[Image] = [];

    entries = os.listdir(i_dir); # Throws if doesn't exist
    for file in entries:
        if (not file.endswith(".csv")): continue;

        csv_pth = os.path.join(i_dir, file);
        img_pth = os.path.abspath(os.path.join(i_dir, "../images", os.path.splitext(file)[0]) + img_ext);
        if (not os.path.exists(img_pth)):
            raise RuntimeError(f"Invalid image found\n  csv: {csv_pth}\n  img: {img_pth}");
        
        # print(csv_pth);
        df = pd.read_csv(csv_pth);

        # Read boxes from the csv
        b_boxes: T.List[Segment] = [];

        for row, data in df.iterrows():
            if (data["label"] != 1):
                print(f"Other label found at {csv_pth}:{row}, ignoring");
                continue;
            
            x=0, y=0, dx=0, dy=0;
            
            if (radius):
                rad = data["radius"];
                cx = data["c-x"];
                cy = data["c-y"];
            
                
            else:

            b_boxes.append(Segment(
                xmin=math.floor(data["x"]),
                ymin=math.floor(data["y"]),
                xmax=math.floor(data["x"] + data["dx"]),
                ymax=math.floor(data["y"] + data["dy"]),
                name=annotation,
                pose=None,
                segmented=None,
                truncated=None,
                difficult=None
            ));
        
        # We now have boxes + image pair so add it to our collection
        images.append(Image(
            img_path=img_pth,
            b_boxes=b_boxes
        ));
    
    return images;



images = get_images("./acfr-fruit-dataset/almonds/annotations", "almond") + get_images("./acfr-fruit-dataset/mangoes/annotations", "mangoes") + get_images("./acfr-fruit-dataset/mangoes/annotations", "apples", radius=True);

images
# Out:
# [Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_59_27_IMG_4463_i2400j3900.png', b_boxes=[Segment(xmin=51, ymin=232, xmax=75, ymax=248, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=35, ymin=240, xmax=51, ymax=262, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_65_21_IMG_4774_i2700j3900.png', b_boxes=[Segment(xmin=16, ymin=175, xmax=50, ymax=213, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=159, ymin=211, xmax=193, ymax=257, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=230, ymin=254, xmax=272, ymax=298, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=196, ymin=94, xmax=236, ymax=128, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=241, ymin=38, xmax=281, ymax=70, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_63_53_IMG_4387_i1500j3900.png', b_boxes=[Segment(xmin=6, ymin=239, xmax=34, ymax=273, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=36, ymin=248, xmax=64, ymax=272, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=253, ymin=182, xmax=281, ymax=206, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=121, ymin=79, xmax=151, ymax=111, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=45, ymin=62, xmax=65, ymax=90, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_58_54_IMG_4729_i900j2400.png', b_boxes=[Segment(xmin=95, ymin=18, xmax=119, ymax=46, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=8, ymin=27, xmax=36, ymax=51, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=93, ymin=239, xmax=121, ymax=263, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_57_43_IMG_4702_i1800j2100.png', b_boxes=[Segment(xmin=1, ymin=100, xmax=17, ymax=128, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=65, ymin=1, xmax=99, ymax=23, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=66, ymin=58, xmax=96, ymax=94, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=80, ymin=155, xmax=110, ymax=191, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=197, ymin=132, xmax=219, ymax=160, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=222, ymin=273, xmax=270, ymax=297, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=250, ymin=265, xmax=280, ymax=297, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_63_16_IMG_4780_i1500j2700.png', b_boxes=[Segment(xmin=28, ymin=108, xmax=68, ymax=146, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=6, ymin=116, xmax=38, ymax=152, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=3, ymin=232, xmax=25, ymax=256, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=88, ymin=83, xmax=122, ymax=113, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=118, ymin=75, xmax=152, ymax=105, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=91, ymin=49, xmax=119, ymax=75, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=107, ymin=28, xmax=135, ymax=54, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=151, ymin=44, xmax=181, ymax=64, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=156, ymin=70, xmax=180, ymax=98, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=165, ymin=122, xmax=185, ymax=150, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=283, ymin=43, xmax=299, ymax=73, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_61_32_IMG_4460_i1500j2400.png', b_boxes=[Segment(xmin=82, ymin=34, xmax=108, ymax=56, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_61_12_IMG_4443_i1200j3600.png', b_boxes=[Segment(xmin=10, ymin=127, xmax=36, ymax=153, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=36, ymin=262, xmax=64, ymax=290, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=24, ymin=161, xmax=50, ymax=183, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=187, ymin=65, xmax=209, ymax=87, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=242, ymin=160, xmax=268, ymax=184, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=262, ymin=156, xmax=288, ymax=180, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=52, ymin=219, xmax=76, ymax=241, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=76, ymin=216, xmax=102, ymax=244, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=66, ymin=256, xmax=104, ymax=282, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=185, ymin=120, xmax=203, ymax=146, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_57_43_IMG_4357_i900j4200.png', b_boxes=[]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_57_09_IMG_4332_i900j1800.png', b_boxes=[Segment(xmin=165, ymin=68, xmax=181, ymax=86, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=66, ymin=158, xmax=82, ymax=176, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=86, ymin=175, xmax=106, ymax=197, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_62_45_IMG_4391_i300j2400.png', b_boxes=[Segment(xmin=0, ymin=19, xmax=34, ymax=43, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=7, ymin=161, xmax=29, ymax=189, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=134, ymin=277, xmax=168, ymax=299, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_61_12_IMG_4681_i900j2100.png', b_boxes=[Segment(xmin=92, ymin=164, xmax=112, ymax=190, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=101, ymin=155, xmax=121, ymax=181, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=180, ymin=136, xmax=200, ymax=162, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=134, ymin=106, xmax=154, ymax=132, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=141, ymin=83, xmax=161, ymax=103, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=125, ymin=78, xmax=149, ymax=102, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=71, ymin=130, xmax=95, ymax=154, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=81, ymin=180, xmax=103, ymax=202, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_59_31_IMG_4694_i1200j2100.png', b_boxes=[Segment(xmin=104, ymin=240, xmax=152, ymax=280, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=122, ymin=211, xmax=156, ymax=245, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=133, ymin=190, xmax=167, ymax=224, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=150, ymin=181, xmax=192, ymax=215, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=106, ymin=147, xmax=144, ymax=181, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=269, ymin=89, xmax=297, ymax=125, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=253, ymin=75, xmax=287, ymax=99, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=84, ymin=192, xmax=118, ymax=216, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_57_57_IMG_4738_i1500j1800.png', b_boxes=[Segment(xmin=104, ymin=125, xmax=136, ymax=147, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=68, ymin=75, xmax=96, ymax=97, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=81, ymin=133, xmax=109, ymax=161, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=116, ymin=148, xmax=144, ymax=176, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=139, ymin=209, xmax=163, ymax=233, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=120, ymin=208, xmax=146, ymax=234, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=81, ymin=219, xmax=101, ymax=245, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=39, ymin=252, xmax=61, ymax=280, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=128, ymin=270, xmax=146, ymax=292, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=137, ymin=236, xmax=159, ymax=262, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=105, ymin=186, xmax=127, ymax=212, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=141, ymin=78, xmax=173, ymax=104, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=204, ymin=103, xmax=236, ymax=129, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=227, ymin=144, xmax=255, ymax=166, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=256, ymin=161, xmax=280, ymax=187, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=254, ymin=122, xmax=286, ymax=144, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=197, ymin=80, xmax=229, ymax=102, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=0, ymin=56, xmax=18, ymax=90, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_57_32_IMG_4466_i1200j600.png', b_boxes=[Segment(xmin=170, ymin=236, xmax=190, ymax=258, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=188, ymin=228, xmax=206, ymax=248, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=187, ymin=208, xmax=207, ymax=230, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=277, ymin=233, xmax=299, ymax=257, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=204, ymin=246, xmax=222, ymax=266, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=97, ymin=71, xmax=117, ymax=93, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=68, ymin=46, xmax=88, ymax=68, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_65_21_IMG_4399_i3000j3000.png', b_boxes=[Segment(xmin=236, ymin=102, xmax=266, ymax=136, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=257, ymin=96, xmax=293, ymax=126, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=51, ymin=49, xmax=75, ymax=79, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_57_43_IMG_4702_i2700j3000.png', b_boxes=[Segment(xmin=157, ymin=19, xmax=195, ymax=51, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=144, ymin=7, xmax=174, ymax=31, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=257, ymin=13, xmax=281, ymax=45, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_56_53_IMG_4373_i1800j2700.png', b_boxes=[Segment(xmin=0, ymin=96, xmax=34, ymax=128, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=214, ymin=97, xmax=248, ymax=129, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=269, ymin=124, xmax=307, ymax=166, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_64_57_IMG_4384_i2700j2400.png', b_boxes=[Segment(xmin=30, ymin=19, xmax=76, ymax=53, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=5, ymin=37, xmax=41, ymax=81, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=41, ymin=48, xmax=65, ymax=74, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=23, ymin=74, xmax=61, ymax=106, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=21, ymin=118, xmax=59, ymax=150, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=10, ymin=167, xmax=44, ymax=199, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=29, ymin=170, xmax=63, ymax=228, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=2, ymin=172, xmax=36, ymax=230, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=133, ymin=263, xmax=181, ymax=295, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=232, ymin=25, xmax=262, ymax=59, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_64_07_IMG_4793_i900j3000.png', b_boxes=[Segment(xmin=11, ymin=222, xmax=39, ymax=248, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=51, ymin=213, xmax=87, ymax=239, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=39, ymin=247, xmax=59, ymax=273, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=56, ymin=248, xmax=82, ymax=274, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=77, ymin=261, xmax=97, ymax=285, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=81, ymin=236, xmax=105, ymax=260, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=173, ymin=228, xmax=205, ymax=252, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=2, ymin=269, xmax=24, ymax=293, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=0, ymin=246, xmax=20, ymax=270, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=164, ymin=181, xmax=186, ymax=205, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=214, ymin=163, xmax=234, ymax=185, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=227, ymin=170, xmax=251, ymax=192, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=232, ymin=191, xmax=256, ymax=215, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=221, ymin=200, xmax=245, ymax=224, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=208, ymin=185, xmax=230, ymax=201, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=256, ymin=241, xmax=274, ymax=257, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=259, ymin=257, xmax=277, ymax=277, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_60_12_IMG_4679_i2400j3300.png', b_boxes=[Segment(xmin=75, ymin=157, xmax=115, ymax=185, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=147, ymin=69, xmax=175, ymax=99, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_65_15_IMG_4451_i1500j1200.png', b_boxes=[Segment(xmin=35, ymin=48, xmax=65, ymax=78, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=66, ymin=56, xmax=96, ymax=82, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=48, ymin=79, xmax=78, ymax=109, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=21, ymin=71, xmax=45, ymax=95, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=19, ymin=229, xmax=39, ymax=249, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=30, ymin=234, xmax=50, ymax=254, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=6, ymin=270, xmax=26, ymax=290, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=70, ymin=143, xmax=94, ymax=167, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=101, ymin=93, xmax=125, ymax=117, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=195, ymin=160, xmax=219, ymax=190, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=203, ymin=188, xmax=225, ymax=208, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=186, ymin=200, xmax=208, ymax=220, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=241, ymin=206, xmax=265, ymax=228, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=265, ymin=187, xmax=289, ymax=209, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=275, ymin=201, xmax=299, ymax=233, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=281, ymin=79, xmax=299, ymax=97, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_64_57_IMG_4744_i1200j2400.png', b_boxes=[Segment(xmin=81, ymin=81, xmax=107, ymax=99, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=73, ymin=89, xmax=99, ymax=107, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=40, ymin=108, xmax=66, ymax=126, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=78, ymin=58, xmax=104, ymax=76, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=131, ymin=88, xmax=163, ymax=114, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=96, ymin=109, xmax=112, ymax=135, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=172, ymin=128, xmax=194, ymax=148, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=185, ymin=143, xmax=207, ymax=167, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=226, ymin=88, xmax=246, ymax=112, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=209, ymin=105, xmax=231, ymax=121, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=230, ymin=115, xmax=248, ymax=133, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=231, ymin=261, xmax=259, ymax=289, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=201, ymin=282, xmax=229, ymax=298, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=170, ymin=1, xmax=190, ymax=23, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_58_10_IMG_4666_i1500j900.png', b_boxes=[Segment(xmin=26, ymin=79, xmax=50, ymax=101, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=12, ymin=86, xmax=32, ymax=104, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=0, ymin=104, xmax=22, ymax=132, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=240, ymin=168, xmax=260, ymax=188, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_61_47_IMG_4485_i1800j4200.png', b_boxes=[Segment(xmin=29, ymin=187, xmax=51, ymax=213, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=113, ymin=196, xmax=133, ymax=222, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=125, ymin=180, xmax=147, ymax=206, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=113, ymin=146, xmax=139, ymax=178, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=119, ymin=29, xmax=139, ymax=55, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_63_18_IMG_4778_i3000j2400.png', b_boxes=[Segment(xmin=6, ymin=130, xmax=40, ymax=170, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=3, ymin=106, xmax=29, ymax=136, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=41, ymin=123, xmax=79, ymax=153, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=68, ymin=102, xmax=110, ymax=142, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=129, ymin=97, xmax=161, ymax=129, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=150, ymin=98, xmax=182, ymax=130, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=15, ymin=26, xmax=45, ymax=58, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=56, ymin=25, xmax=80, ymax=57, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=135, ymin=4, xmax=163, ymax=38, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=233, ymin=65, xmax=269, ymax=99, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=225, ymin=128, xmax=255, ymax=162, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=30, ymin=201, xmax=60, ymax=235, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=38, ymin=221, xmax=68, ymax=255, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=118, ymin=246, xmax=152, ymax=284, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=151, ymin=187, xmax=191, ymax=221, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=181, ymin=210, xmax=221, ymax=244, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=173, ymin=235, xmax=205, ymax=271, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_65_56_IMG_4748_i900j4200.png', b_boxes=[Segment(xmin=105, ymin=63, xmax=121, ymax=89, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=140, ymin=71, xmax=156, ymax=97, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_57_57_IMG_4738_i1500j1500.png', b_boxes=[Segment(xmin=46, ymin=38, xmax=76, ymax=58, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_57_09_IMG_4332_i1800j2100.png', b_boxes=[Segment(xmin=91, ymin=113, xmax=107, ymax=131, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=108, ymin=110, xmax=124, ymax=128, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=83, ymin=39, xmax=101, ymax=59, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=272, ymin=157, xmax=290, ymax=181, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=4, ymin=92, xmax=26, ymax=116, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_64_07_IMG_4409_i600j2100.png', b_boxes=[Segment(xmin=264, ymin=244, xmax=292, ymax=272, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=249, ymin=236, xmax=277, ymax=262, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=238, ymin=251, xmax=270, ymax=277, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=246, ymin=279, xmax=274, ymax=299, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=181, ymin=278, xmax=209, ymax=298, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=157, ymin=253, xmax=185, ymax=277, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=146, ymin=230, xmax=176, ymax=256, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=133, ymin=251, xmax=163, ymax=277, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=105, ymin=221, xmax=129, ymax=241, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=86, ymin=119, xmax=112, ymax=141, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=1, ymin=82, xmax=27, ymax=114, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=35, ymin=279, xmax=61, ymax=299, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_65_35_IMG_4762_i2400j1200.png', b_boxes=[Segment(xmin=12, ymin=2, xmax=42, ymax=24, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=67, ymin=48, xmax=97, ymax=80, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=6, ymin=106, xmax=34, ymax=136, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=45, ymin=90, xmax=73, ymax=120, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=92, ymin=110, xmax=114, ymax=138, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=1, ymin=162, xmax=23, ymax=194, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=14, ymin=196, xmax=34, ymax=220, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=186, ymin=180, xmax=212, ymax=204, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=230, ymin=179, xmax=256, ymax=203, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=218, ymin=202, xmax=250, ymax=230, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=242, ymin=10, xmax=274, ymax=38, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=260, ymin=1, xmax=292, ymax=29, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=117, ymin=61, xmax=137, ymax=83, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_57_32_IMG_4467_i2100j4500.png', b_boxes=[Segment(xmin=14, ymin=40, xmax=42, ymax=68, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=44, ymin=35, xmax=66, ymax=65, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_63_30_IMG_4769_i300j2100.png', b_boxes=[Segment(xmin=45, ymin=268, xmax=77, ymax=296, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=162, ymin=197, xmax=194, ymax=225, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=216, ymin=244, xmax=248, ymax=272, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=249, ymin=245, xmax=279, ymax=271, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=240, ymin=38, xmax=270, ymax=64, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_63_11_IMG_4786_i1800j1200.png', b_boxes=[Segment(xmin=63, ymin=184, xmax=89, ymax=214, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=55, ymin=149, xmax=85, ymax=181, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=115, ymin=75, xmax=145, ymax=99, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=128, ymin=94, xmax=158, ymax=118, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=175, ymin=100, xmax=205, ymax=124, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=237, ymin=144, xmax=263, ymax=172, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=248, ymin=128, xmax=274, ymax=152, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=255, ymin=33, xmax=277, ymax=55, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=110, ymin=38, xmax=128, ymax=58, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_63_07_IMG_4439_i2100j4500.png', b_boxes=[]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_59_02_IMG_4343_i2100j300.png', b_boxes=[Segment(xmin=63, ymin=124, xmax=77, ymax=140, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=73, ymin=124, xmax=87, ymax=138, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=64, ymin=116, xmax=78, ymax=130, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=61, ymin=105, xmax=75, ymax=119, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=31, ymin=106, xmax=45, ymax=120, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=30, ymin=117, xmax=44, ymax=131, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=0, ymin=141, xmax=14, ymax=155, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=105, ymin=134, xmax=119, ymax=148, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=122, ymin=143, xmax=136, ymax=157, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=131, ymin=143, xmax=145, ymax=157, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=123, ymin=134, xmax=137, ymax=148, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=71, ymin=50, xmax=85, ymax=64, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=78, ymin=43, xmax=92, ymax=57, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=67, ymin=46, xmax=81, ymax=60, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=61, ymin=40, xmax=75, ymax=54, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=67, ymin=34, xmax=81, ymax=48, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=82, ymin=33, xmax=96, ymax=47, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=57, ymin=11, xmax=71, ymax=25, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=245, ymin=257, xmax=259, ymax=271, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=225, ymin=255, xmax=239, ymax=269, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=262, ymin=263, xmax=276, ymax=277, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=255, ymin=273, xmax=269, ymax=287, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=101, ymin=254, xmax=127, ymax=274, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=27, ymin=281, xmax=59, ymax=301, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_63_50_IMG_4490_i2700j2700.png', b_boxes=[Segment(xmin=63, ymin=179, xmax=87, ymax=205, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=79, ymin=170, xmax=103, ymax=198, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=88, ymin=121, xmax=118, ymax=157, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=49, ymin=125, xmax=77, ymax=153, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=64, ymin=35, xmax=92, ymax=69, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=122, ymin=35, xmax=150, ymax=57, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=129, ymin=9, xmax=159, ymax=33, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=265, ymin=154, xmax=293, ymax=182, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=165, ymin=18, xmax=195, ymax=44, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=198, ymin=1, xmax=224, ymax=23, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_61_51_IMG_4482_i2100j2700.png', b_boxes=[Segment(xmin=106, ymin=100, xmax=132, ymax=120, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=98, ymin=124, xmax=122, ymax=146, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=90, ymin=167, xmax=114, ymax=189, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_58_05_IMG_4341_i1500j1500.png', b_boxes=[Segment(xmin=84, ymin=263, xmax=108, ymax=295, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=91, ymin=236, xmax=119, ymax=264, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=83, ymin=214, xmax=109, ymax=240, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=118, ymin=194, xmax=144, ymax=220, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=91, ymin=179, xmax=117, ymax=215, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=82, ymin=154, xmax=108, ymax=190, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=41, ymin=191, xmax=75, ymax=215, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=129, ymin=128, xmax=157, ymax=152, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=84, ymin=106, xmax=108, ymax=134, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=87, ymin=81, xmax=111, ymax=105, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=72, ymin=52, xmax=102, ymax=80, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=55, ymin=38, xmax=85, ymax=58, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=182, ymin=142, xmax=202, ymax=164, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_57_09_IMG_4661_i600j2700.png', b_boxes=[Segment(xmin=0, ymin=35, xmax=24, ymax=57, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=7, ymin=108, xmax=31, ymax=130, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_63_30_IMG_4458_i2700j2100.png', b_boxes=[Segment(xmin=39, ymin=213, xmax=65, ymax=249, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=39, ymin=136, xmax=71, ymax=164, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=76, ymin=5, xmax=108, ymax=33, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=1, ymin=42, xmax=23, ymax=80, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=2, ymin=2, xmax=24, ymax=36, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=68, ymin=66, xmax=94, ymax=88, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_61_01_IMG_4436_i2700j2400.png', b_boxes=[Segment(xmin=23, ymin=177, xmax=57, ymax=211, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=35, ymin=125, xmax=69, ymax=159, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=66, ymin=107, xmax=100, ymax=135, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=86, ymin=129, xmax=120, ymax=173, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=94, ymin=63, xmax=132, ymax=99, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=131, ymin=28, xmax=169, ymax=58, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=65, ymin=162, xmax=97, ymax=200, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=114, ymin=235, xmax=142, ymax=261, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=126, ymin=210, xmax=156, ymax=234, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=43, ymin=222, xmax=73, ymax=246, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=259, ymin=76, xmax=293, ymax=108, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_61_51_IMG_4482_i2700j1800.png', b_boxes=[Segment(xmin=131, ymin=30, xmax=163, ymax=62, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=217, ymin=109, xmax=235, ymax=135, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=98, ymin=8, xmax=130, ymax=30, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_61_12_IMG_4443_i1800j600.png', b_boxes=[Segment(xmin=0, ymin=208, xmax=18, ymax=246, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromEast_63_53_IMG_4388_i2100j3600.png', b_boxes=[Segment(xmin=227, ymin=57, xmax=253, ymax=91, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=129, ymin=259, xmax=151, ymax=281, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=13, ymin=184, xmax=51, ymax=214, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/almonds/images/fromWest_57_09_IMG_4661_i1200j1500.png', b_boxes=[Segment(xmin=163, ymin=133, xmax=187, ymax=155, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=184, ymin=125, xmax=204, ymax=147, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=75, ymin=171, xmax=91, ymax=193, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=58, ymin=207, xmax=74, ymax=229, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
# ...
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T031255.544449_i1606j766.png', b_boxes=[Segment(xmin=113, ymin=398, xmax=137, ymax=425, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=138, ymin=419, xmax=157, ymax=446, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=60, ymin=353, xmax=84, ymax=385, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=106, ymin=355, xmax=125, ymax=381, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T041935.578460_i2406j1434.png', b_boxes=[Segment(xmin=8, ymin=149, xmax=44, ymax=193, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=20, ymin=57, xmax=56, ymax=102, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=136, ymin=18, xmax=176, ymax=67, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=157, ymin=4, xmax=197, ymax=36, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=446, ymin=3, xmax=472, ymax=35, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T024351.594653_i2085j772.png', b_boxes=[Segment(xmin=254, ymin=163, xmax=300, ymax=217, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=97, ymin=108, xmax=134, ymax=151, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=418, ymin=132, xmax=467, ymax=190, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=298, ymin=331, xmax=324, ymax=362, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=40, ymin=211, xmax=63, ymax=241, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T024457.995697_i1542j1120.png', b_boxes=[Segment(xmin=67, ymin=300, xmax=116, ymax=352, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=74, ymin=256, xmax=114, ymax=298, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=284, ymin=467, xmax=332, ymax=517, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=479, ymin=422, xmax=526, ymax=473, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=401, ymin=101, xmax=440, ymax=151, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T025012.531796_i1934j747.png', b_boxes=[Segment(xmin=2, ymin=112, xmax=29, ymax=156, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=297, ymin=37, xmax=331, ymax=86, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=320, ymin=22, xmax=353, ymax=61, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=342, ymin=422, xmax=375, ymax=465, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=343, ymin=464, xmax=380, ymax=498, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T024437.795537_i1792j1246.png', b_boxes=[Segment(xmin=391, ymin=344, xmax=418, ymax=372, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=410, ymin=22, xmax=434, ymax=48, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T041555.527699_i1507j1046.png', b_boxes=[]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T043058.386236_i1882j422.png', b_boxes=[Segment(xmin=4, ymin=194, xmax=41, ymax=228, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=31, ymin=216, xmax=68, ymax=253, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=57, ymin=251, xmax=102, ymax=297, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=126, ymin=174, xmax=166, ymax=220, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=156, ymin=216, xmax=193, ymax=257, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=230, ymin=227, xmax=266, ymax=268, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=304, ymin=173, xmax=341, ymax=214, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=344, ymin=175, xmax=377, ymax=212, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=335, ymin=140, xmax=368, ymax=177, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=470, ymin=215, xmax=499, ymax=259, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T031552.311879_i2207j90.png', b_boxes=[Segment(xmin=118, ymin=35, xmax=155, ymax=79, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=167, ymin=22, xmax=208, ymax=70, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=453, ymin=254, xmax=474, ymax=279, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=145, ymin=3, xmax=184, ymax=41, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T044018.044623_i1463j1130.png', b_boxes=[Segment(xmin=122, ymin=263, xmax=154, ymax=299, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T030604.014803_i1820j459.png', b_boxes=[Segment(xmin=137, ymin=14, xmax=175, ymax=50, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=256, ymin=76, xmax=294, ymax=116, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=282, ymin=78, xmax=310, ymax=114, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=452, ymin=20, xmax=497, ymax=71, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=222, ymin=274, xmax=266, ymax=325, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=188, ymin=357, xmax=225, ymax=404, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=262, ymin=478, xmax=298, ymax=524, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T030529.269118_i2388j95.png', b_boxes=[Segment(xmin=146, ymin=44, xmax=210, ymax=109, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=264, ymin=1, xmax=321, ymax=32, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=365, ymin=23, xmax=403, ymax=70, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=370, ymin=248, xmax=435, ymax=332, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T044457.820659_i1207j1457.png', b_boxes=[]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T045111.953046_i1573j88.png', b_boxes=[Segment(xmin=0, ymin=312, xmax=35, ymax=358, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=150, ymin=380, xmax=189, ymax=421, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=180, ymin=388, xmax=219, ymax=429, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=225, ymin=366, xmax=256, ymax=400, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=257, ymin=377, xmax=286, ymax=407, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=283, ymin=390, xmax=318, ymax=424, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=305, ymin=413, xmax=343, ymax=450, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=339, ymin=410, xmax=377, ymax=447, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=215, ymin=422, xmax=253, ymax=463, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T030915.963602_i2016j1152.png', b_boxes=[]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T043122.648206_i2066j1924.png', b_boxes=[Segment(xmin=170, ymin=141, xmax=210, ymax=188, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=174, ymin=356, xmax=215, ymax=403, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T030103.066494_i1816j77.png', b_boxes=[]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T041816.576881_i1636j1386.png', b_boxes=[Segment(xmin=370, ymin=434, xmax=422, ymax=489, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T031007.849387_i1720j874.png', b_boxes=[Segment(xmin=130, ymin=213, xmax=158, ymax=246, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=342, ymin=325, xmax=375, ymax=364, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=150, ymin=409, xmax=176, ymax=440, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=293, ymin=398, xmax=313, ymax=426, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=313, ymin=392, xmax=333, ymax=417, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=450, ymin=466, xmax=475, ymax=496, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T025717.937616_i1526j1764.png', b_boxes=[]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T043156.891241_i2031j1134.png', b_boxes=[]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T044601.654568_i1484j1339.png', b_boxes=[Segment(xmin=15, ymin=290, xmax=71, ymax=359, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=107, ymin=220, xmax=157, ymax=282, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=307, ymin=339, xmax=368, ymax=401, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T031328.386291_i2154j51.png', b_boxes=[Segment(xmin=433, ymin=136, xmax=458, ymax=164, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=424, ymin=115, xmax=452, ymax=145, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=448, ymin=23, xmax=470, ymax=50, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=453, ymin=37, xmax=475, ymax=64, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=268, ymin=33, xmax=304, ymax=72, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=268, ymin=70, xmax=304, ymax=109, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=238, ymin=35, xmax=276, ymax=66, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=219, ymin=18, xmax=250, ymax=49, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=76, ymin=120, xmax=114, ymax=157, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=22, ymin=37, xmax=62, ymax=70, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=363, ymin=81, xmax=392, ymax=113, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=372, ymin=122, xmax=395, ymax=147, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=282, ymin=150, xmax=324, ymax=181, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=275, ymin=137, xmax=299, ymax=157, name='almond', pose=None, segmented=None, truncated=None, difficult=None), Segment(xmin=90, ymin=66, xmax=132, ymax=112, name='almond', pose=None, segmented=None, truncated=None, difficult=None)]),
#  Image(img_path='/mnt/4b92d4ee-d89f-4ff6-9584-a00287776fe8/doi_10_5061_dryad_63xsj3v34__v20210831/acfr-fruit-dataset/mangoes/images/20151124T024808.199798_i2651j1872.png', b_boxes=[]),
#  ...]

# %%
# Define a struct fot the dataset json used in Adrian's code

@dataclass
class A_Annotation:
    # ID of this annotation?
    id: int;
    # ID of the relevant image
    image_id: int;
    # List of 4 ints
    bbox: T.List[int];
    # Id of the category
    category_id: int;

    # This is seemingly always 1.0
    # Need to look further into code
    area: float;
    # Unsure
    iscrowd: int;

@dataclass
class A_Category:
    # ID of category
    id: int;
    name: str;
    supercategory: str;

@dataclass
class A_Image:
    id: int;
    file_name: str;
    width: int;
    height: int;
    
@dataclass
class A_Dataset:
    annotations: T.List[A_Annotation];
    categories: T.List[A_Category];
    images: T.List[A_Image];

species_map = {"almond": 0};
species_list = ["almond"];

# %%
# Create the dataset and add the categories
categories = [];
for i, sp in enumerate(species_list):
    categories.append( A_Category(i, sp, sp) );

# Add all of the images and their bounding boxes

new_dataset_path = "./almond_ds";
if (os.path.exists(new_dataset_path)):
    # rm -r in python taken from https://stackoverflow.com/a/43757091
    shutil.rmtree(new_dataset_path);

os.mkdir(new_dataset_path);
image_dir = os.path.join(new_dataset_path, "all")
os.mkdir(image_dir);


def make_json_list(name: str, images):
    imlist = [];

    for img in images:
        imlist.append(os.path.basename(img.img_path));

    json_ds_handle = open(os.path.join( new_dataset_path, name ), "w");

    # JSON serialise class solution from this S/O comment: https://stackoverflow.com/questions/10252010/serializing-class-instance-to-json#comment82536156_10252010
    json_ds_handle.write(json.dumps(imlist, default=lambda x: x.__dict__, indent=4));
    json_ds_handle.flush();
    json_ds_handle.close();

def make_adrian_ds(name: str, images):
    ads = A_Dataset([], [], []);
    ads.categories = categories;
    
    bbox_id = 0;

    for img_id, img in enumerate(images):
        # Read image for size
        cv_image = cv2.imread(img.img_path);

        # Create entries in our new dataset format
        ads.images.append(A_Image(
            img_id,
            os.path.basename(img.img_path),
            cv_image.shape[1],
            cv_image.shape[0]
        ));

        if (not os.path.exists(os.path.join(os.path.abspath(new_dataset_path), "all", os.path.basename(img.img_path)))):
            os.symlink(
                os.path.abspath(img.img_path),
                os.path.join(os.path.abspath(new_dataset_path), "all", os.path.basename(img.img_path))
            );

        # Add this image's bounding boxes
        density_bboxes = [];
        for bbox in img.b_boxes:
            density_bboxes.append([bbox.xmin, bbox.ymin]);
            density_bboxes.append([bbox.xmax, bbox.ymax]);
            ads.annotations.append(A_Annotation(
                id=bbox_id,
                image_id=img_id,
                bbox=[ bbox.xmin, bbox.ymin, bbox.xmax, bbox.ymax ],
                category_id=species_map[bbox.name],
                area=1.0,
                iscrowd=0
            ));
            
            bbox_id += 1;
        
        np.savetxt(os.path.join(new_dataset_path, "all", os.path.basename(img.img_path)) + ".txt", density_bboxes);


    json_ds_handle = open(os.path.join( new_dataset_path, name ), "w");

    # JSON serialise class solution from this S/O comment: https://stackoverflow.com/questions/10252010/serializing-class-instance-to-json#comment82536156_10252010
    json_ds_handle.write(json.dumps(ads, default=lambda x: x.__dict__, indent=4));
    json_ds_handle.flush();
    json_ds_handle.close();

# %%
# Shuffle the images
imagenp = np.array(images);
np.random.shuffle(imagenp);

make_adrian_ds("dataset.json", imagenp);
# Split into train test validation

img_count = len(imagenp);
train_max = math.ceil(img_count * 0.7);
test_max  = math.ceil(img_count * 0.2) + train_max;
val_max   = img_count;

print(f"train: [0:{train_max}], test: [{train_max}:{test_max}], val: [{test_max}:{val_max}]");

make_json_list("json_train_set.json", imagenp[0:train_max]);
make_json_list("json_test_set.json", imagenp[train_max:test_max]);
make_json_list("json_val_set.json", imagenp[test_max:val_max]);
# Out:
# train: [0:434], test: [434:558], val: [558:620]
